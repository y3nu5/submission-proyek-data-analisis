# %% [markdown]
# # Proyek Analisis Data: [E-Commerce Public Dataset]
# - **Nama:** Muhammad Yunus
# - **Email:** CDCC116D6Y0980@student.devacademy.id
# - **ID Dicoding:** muhammad_yunus_LCR9

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# **SMART Question** adalah sebuah framework untuk merumuskan pertanyaan secara terstruktur agar memeperoleh informasi yang mendalam.
#
# * **Spesific (Spesifik)**
#   * Pertanyaan harus jelas, fokus pada sebuah topik tertentu, dan tidak bermakna ganda. Hindari pertanyaan yang terlalu luas.
#     * Salah: Bagaimana cara meningkatkan penjualan?
#     * Benar: Faktor apa saja yang memengaruhi penurunan penjualan produk kategori elektronik di wilayah Jakarta selama kuartal terakhir?
# * **Measurable (Terukur)**
#   * Pertanyaan harus bisa dijawab dengan angka atau matrix yang konkret, harus tahu apa yang akan dihitung.
#     * Salah: Apakah pelanggan senang dengan layanan kita?
#     * Benar: Berapa skor rata-rata Customer Satisfaction untuk layanan purna jual bulan ini dibandingkan bulan lalu?
# * **Action-Oriented (Berorientasi Aksi)**
#   * Hasil dari pertanyaan harus bisa memberikan arahan untuk melakukan tindakan nyata. Jika pertanyaan terjawab, stakeholder harus tahu apa langkah selanjutnya.
#     * Salah: Mengapa orang suka berbelanja?
#     * Benar: Fitur apa pada aplikasi yang paling sering digunakan sebelum pengguna memutuskan untuk melakukan checkout?
# * **Relevant (Relevan)**
#   * Hasil dari pertanyaan harus sejalan dengan tujuan utama bisnis atau masalah yang sedang dihadapi.
#     * Salah: Menanyakan tentang stok gudang saat masalah utamanya adalah efektivitas kampanye media sosial.
#     * Benar: Apakah kampanye iklan di Instagram memberikan Return on Ad Spend (ROAS) yang lebih tinggi dibandingkan iklan di TikTok?
# * **Time-bound (Terikat Waktu)**
#   * Pertanyaan harus ada batasan waktu yang jelas agar analisis memiliki konteks yang tepat.
#     * Salah: Berapa banyak pengguna baru kita?
#     * Benar: Berapa tingkat pertumbuhan pengguna baru secara bulanan (Month-over-Month) sepanjang tahun 2025?

# %% [markdown]
# **Contoh pertanyaan bisnis yang memenuhi seluruh elemen SMART**
#
# ***"Faktor apa saja yang memengaruhi penurunan conversion rate pada pengguna aplikasi Android di wilayah Jabodetabek sebesar 5% selama periode Flash Sale Maret 2026?"***
#
# Keterangan:
#
# - **Specific**: Fokus pada "penurunan conversion rate" untuk "aplikasi Android" di "Jabodetabek". Bukan sekadar penjualan turun.
# - **Measurable**: Ada angka konkret yang ingin dianalisis, yaitu penurunan sebesar "5%".
# - **Action-Oriented**: Dengan mengetahui faktor penyebabnya misalnya bug pada versi Android tertentu atau kendala logistik di Jabodetabek, tim bisa langsung melakukan perbaikan teknis atau operasional.
# - **Relevant**: Penurunan konversi saat Flash Sale adalah masalah kritis bagi bisnis retail/e-commerce.
# - **Time-bound**: Dibatasi pada periode spesifik "Flash Sale Maret 2026".

# %% [markdown]
# - **Pertanyaan 1:** Bagaimana distribusi review score pelanggan pada 3 bulan terakhir?
# - **Pertanyaan 2:** Kategori produk apa yang memiliki jumlah penjualan tertinggi berdasarkan jumlah transaksi pada periode 2017-2018?

# %% [markdown]
# ## Import Semua Packages/Library yang Digunakan

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %% [markdown]
# ####load customers_df

# %%
customers_df = pd.read_csv("/content/customers_dataset.csv")

customers_df.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP

# %% [markdown]
# #### load geolocation_df

# %%
geolocation_df = pd.read_csv("/content/geolocation_dataset.csv")

geolocation_df.head()
# Out:
#    geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                         1037       -23.545621       -46.639292
# 1                         1046       -23.546081       -46.644820
# 2                         1046       -23.546129       -46.642951
# 3                         1041       -23.544392       -46.639499
# 4                         1035       -23.541578       -46.641607
#
#   geolocation_city geolocation_state
# 0        sao paulo                SP
# 1        sao paulo                SP
# 2        sao paulo                SP
# 3        sao paulo                SP
# 4        sao paulo                SP

# %% [markdown]
# ####load order_items_df

# %%
order_items_df = pd.read_csv("/content/order_items_dataset.csv")

order_items_df.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value
# 0  2017-09-19 09:45:35   58.90          13.29
# 1  2017-05-03 11:05:13  239.90          19.93
# 2  2018-01-18 14:48:30  199.00          17.87
# 3  2018-08-15 10:10:18   12.99          12.79
# 4  2017-02-13 13:57:51  199.90          18.14

# %% [markdown]
# ####load order_payments_df

# %%
order_payments_df = pd.read_csv("/content/order_payments_dataset.csv")

order_payments_df.head()
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  42fdf880ba16b47b59251dd489d4441a                   1  credit_card
#
#    payment_installments  payment_value
# 0                     8          99.33
# 1                     1          24.39
# 2                     1          65.71
# 3                     8         107.78
# 4                     2         128.45

# %% [markdown]
# ####load order_reviews_df

# %%
order_reviews_df = pd.read_csv("/content/order_reviews_dataset.csv")

order_reviews_df.head()
# Out:
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3  e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4  f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
#
#    review_score review_comment_title  \
# 0             4                  NaN
# 1             5                  NaN
# 2             5                  NaN
# 3             5                  NaN
# 4             5                  NaN
#
#                               review_comment_message review_creation_date  \
# 0                                                NaN  2018-01-18 00:00:00
# 1                                                NaN  2018-03-10 00:00:00
# 2                                                NaN  2018-02-17 00:00:00
# 3              Recebi bem antes do prazo estipulado.  2017-04-21 00:00:00
# 4  Parabéns lojas lannister adorei comprar pela I...  2018-03-01 00:00:00
#
#   review_answer_timestamp
# 0     2018-01-18 21:46:59
# 1     2018-03-11 03:05:13
# 2     2018-02-18 14:36:24
# 3     2017-04-21 22:02:06
# 4     2018-03-02 10:26:53

# %% [markdown]
# ####load orders_df

# %%
orders_df = pd.read_csv("/content/orders_dataset.csv")

orders_df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# 1          2018-07-26 14:31:00           2018-08-07 15:27:45
# 2          2018-08-08 13:50:00           2018-08-17 18:06:29
# 3          2017-11-22 13:39:59           2017-12-02 00:28:42
# 4          2018-02-14 19:46:34           2018-02-16 18:17:02
#
#   order_estimated_delivery_date
# 0           2017-10-18 00:00:00
# 1           2018-08-13 00:00:00
# 2           2018-09-04 00:00:00
# 3           2017-12-15 00:00:00
# 4           2018-02-26 00:00:00

# %% [markdown]
# ####load product_category_df

# %%
product_category_df = pd.read_csv("/content/product_category_name_translation.csv")

product_category_df.head()
# Out:
#     product_category_name product_category_name_english
# 0            beleza_saude                 health_beauty
# 1  informatica_acessorios         computers_accessories
# 2              automotivo                          auto
# 3         cama_mesa_banho                bed_bath_table
# 4        moveis_decoracao               furniture_decor

# %% [markdown]
# ####load Products_df

# %%
products_df = pd.read_csv("/content/products_dataset.csv")

products_df.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 0             225.0               16.0               10.0              14.0
# 1            1000.0               30.0               18.0              20.0
# 2             154.0               18.0                9.0              15.0
# 3             371.0               26.0                4.0              26.0
# 4             625.0               20.0               17.0              13.0

# %% [markdown]
# ####load sellers_df

# %%
sellers_df = pd.read_csv("/content/sellers_dataset.csv")

sellers_df.head()
# Out:
#                           seller_id  seller_zip_code_prefix  \
# 0  3442f8959a84dea7ee197c632cb2df15                   13023
# 1  d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2  ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3  c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4  51a04a8a6bdcb23deccc82b0b80742cf                   12914
#
#          seller_city seller_state
# 0           campinas           SP
# 1         mogi guacu           SP
# 2     rio de janeiro           RJ
# 3          sao paulo           SP
# 4  braganca paulista           SP

# %% [markdown]
# ###Assessing Data

# %% [markdown]
# #### Identifying customers_df problem

# %%
customers_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_id               99441 non-null  object
#  1   customer_unique_id        99441 non-null  object
#  2   customer_zip_code_prefix  99441 non-null  int64
#  3   customer_city             99441 non-null  object
#  4   customer_state            99441 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 3.8+ MB

# %%
customers_df.isna().sum()
# Out:
# customer_id                 0
# customer_unique_id          0
# customer_zip_code_prefix    0
# customer_city               0
# customer_state              0
# dtype: int64

# %%
print("Jumlah duplikasi", customers_df.duplicated().sum())
# Out:
# Jumlah duplikasi 0

# %%
customers_df.describe()
# Out:
#        customer_zip_code_prefix
# count              99441.000000
# mean               35137.474583
# std                29797.938996
# min                 1003.000000
# 25%                11347.000000
# 50%                24416.000000
# 75%                58900.000000
# max                99990.000000

# %% [markdown]
# **Steps to Take:**
# - data sudah bersih, sehingga tidak ada langkah penanganan di tahap data cleaning

# %% [markdown]
# #### Identifying geolocation_df problem

# %%
geolocation_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000163 entries, 0 to 1000162
# Data columns (total 5 columns):
#  #   Column                       Non-Null Count    Dtype
# ---  ------                       --------------    -----
#  0   geolocation_zip_code_prefix  1000163 non-null  int64
#  1   geolocation_lat              1000163 non-null  float64
#  2   geolocation_lng              1000163 non-null  float64
#  3   geolocation_city             1000163 non-null  object
#  4   geolocation_state            1000163 non-null  object
# dtypes: float64(2), int64(1), object(2)
# memory usage: 38.2+ MB

# %%
geolocation_df.isna().sum()
# Out:
# geolocation_zip_code_prefix    0
# geolocation_lat                0
# geolocation_lng                0
# geolocation_city               0
# geolocation_state              0
# dtype: int64

# %%
print("Jumlah duplikasi", geolocation_df.duplicated().sum())
# Out:
# Jumlah duplikasi 261831

# %%
geolocation_df.describe()
# Out:
#        geolocation_zip_code_prefix  geolocation_lat  geolocation_lng
# count                 1.000163e+06     1.000163e+06     1.000163e+06
# mean                  3.657417e+04    -2.117615e+01    -4.639054e+01
# std                   3.054934e+04     5.715866e+00     4.269748e+00
# min                   1.001000e+03    -3.660537e+01    -1.014668e+02
# 25%                   1.107500e+04    -2.360355e+01    -4.857317e+01
# 50%                   2.653000e+04    -2.291938e+01    -4.663788e+01
# 75%                   6.350400e+04    -1.997962e+01    -4.376771e+01
# max                   9.999000e+04     4.506593e+01     1.211054e+02

# %% [markdown]
# **Steps to Take:**
# - Menghapus data duplikat

# %% [markdown]
# #### Identifying order_items_df problem

# %%
order_items_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   order_id             112650 non-null  object
#  1   order_item_id        112650 non-null  int64
#  2   product_id           112650 non-null  object
#  3   seller_id            112650 non-null  object
#  4   shipping_limit_date  112650 non-null  object
#  5   price                112650 non-null  float64
#  6   freight_value        112650 non-null  float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 6.0+ MB

# %%
order_items_df.isna().sum()
# Out:
# order_id               0
# order_item_id          0
# product_id             0
# seller_id              0
# shipping_limit_date    0
# price                  0
# freight_value          0
# dtype: int64

# %%
print("Jumlah duplikasi", orders_df.duplicated().sum())
# Out:
# Jumlah duplikasi 0

# %%
order_items_df.describe()
# Out:
#        order_item_id          price  freight_value
# count  112650.000000  112650.000000  112650.000000
# mean        1.197834     120.653739      19.990320
# std         0.705124     183.633928      15.806405
# min         1.000000       0.850000       0.000000
# 25%         1.000000      39.900000      13.080000
# 50%         1.000000      74.990000      16.260000
# 75%         1.000000     134.900000      21.150000
# max        21.000000    6735.000000     409.680000

# %% [markdown]
# **Steps to Take:**
# - mengubah tipe data kolom shipping_limit_date menjadi datetime

# %% [markdown]
# #### Identifying order_payents_df problem

# %%
order_payments_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103886 entries, 0 to 103885
# Data columns (total 5 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   order_id              103886 non-null  object
#  1   payment_sequential    103886 non-null  int64
#  2   payment_type          103886 non-null  object
#  3   payment_installments  103886 non-null  int64
#  4   payment_value         103886 non-null  float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 4.0+ MB

# %%
order_payments_df.isna().sum()
# Out:
# order_id                0
# payment_sequential      0
# payment_type            0
# payment_installments    0
# payment_value           0
# dtype: int64

# %%
print("Jumlah duplikasi", order_payments_df.duplicated().sum())
# Out:
# Jumlah duplikasi 0

# %%
order_payments_df.describe()
# Out:
#        payment_sequential  payment_installments  payment_value
# count       103886.000000         103886.000000  103886.000000
# mean             1.092679              2.853349     154.100380
# std              0.706584              2.687051     217.494064
# min              1.000000              0.000000       0.000000
# 25%              1.000000              1.000000      56.790000
# 50%              1.000000              1.000000     100.000000
# 75%              1.000000              4.000000     171.837500
# max             29.000000             24.000000   13664.080000

# %% [markdown]
# **Steps to Take:**
# - data sudah bersih, sehingga tidak ada penanganan lanjutan di tahap data cleaning

# %% [markdown]
# #### Identifying order_reviews_df problem

# %%
order_reviews_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99224 entries, 0 to 99223
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   review_id                99224 non-null  object
#  1   order_id                 99224 non-null  object
#  2   review_score             99224 non-null  int64
#  3   review_comment_title     11568 non-null  object
#  4   review_comment_message   40977 non-null  object
#  5   review_creation_date     99224 non-null  object
#  6   review_answer_timestamp  99224 non-null  object
# dtypes: int64(1), object(6)
# memory usage: 5.3+ MB

# %%
order_reviews_df.isna().sum()
# Out:
# review_id                      0
# order_id                       0
# review_score                   0
# review_comment_title       87656
# review_comment_message     58247
# review_creation_date           0
# review_answer_timestamp        0
# dtype: int64

# %%
print("jumlah duplikasi", order_reviews_df.duplicated().sum())
# Out:
# jumlah duplikasi 0

# %%
order_reviews_df.describe()
# Out:
#        review_score
# count  99224.000000
# mean       4.086421
# std        1.347579
# min        1.000000
# 25%        4.000000
# 50%        5.000000
# 75%        5.000000
# max        5.000000

# %% [markdown]
# **Steps to Take:**
# - Mengisi kolo review_comment_title dan review_comment_massage masing masing No title dan No review
# -  mengubah tipe data kolom review creation date dan review answer menjadi datetime

# %% [markdown]
# #### Identifying orders_df problem

# %%
orders_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  object
#  4   order_approved_at              99281 non-null  object
#  5   order_delivered_carrier_date   97658 non-null  object
#  6   order_delivered_customer_date  96476 non-null  object
#  7   order_estimated_delivery_date  99441 non-null  object
# dtypes: object(8)
# memory usage: 6.1+ MB

# %%
orders_df.isna().sum()
# Out:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 160
# order_delivered_carrier_date     1783
# order_delivered_customer_date    2965
# order_estimated_delivery_date       0
# dtype: int64

# %%
print("Jumlah duplikasi", orders_df.duplicated().sum())
# Out:
# Jumlah duplikasi 0

# %%
orders_df.describe()
# Out:
#                                 order_id                       customer_id  \
# count                              99441                             99441
# unique                             99441                             99441
# top     66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
# freq                                   1                                 1
#
#        order_status order_purchase_timestamp    order_approved_at  \
# count         99441                    99441                99281
# unique            8                    98875                90733
# top       delivered      2018-08-02 12:06:07  2018-02-27 04:31:10
# freq          96478                        3                    9
#
#        order_delivered_carrier_date order_delivered_customer_date  \
# count                         97658                         96476
# unique                        81018                         95664
# top             2018-05-09 15:48:00           2018-05-14 20:02:44
# freq                             47                             3
#
#        order_estimated_delivery_date
# count                          99441
# unique                           459
# top              2017-12-20 00:00:00
# freq                             522

# %% [markdown]
# **Steps to Take:**
# - Membiarkan missing value di kolom order approved, order delivered customer date, dan order estimate delivery date, karena kemungkinan kejadian tersebut belum terjadi
# -  mengubah tipe data kolom delivered carrier, customer, dan delivery menjadi datetime

# %% [markdown]
# #### Identifying product_category_df problem

# %%
product_category_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71 entries, 0 to 70
# Data columns (total 2 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   product_category_name          71 non-null     object
#  1   product_category_name_english  71 non-null     object
# dtypes: object(2)
# memory usage: 1.2+ KB

# %%
product_category_df.isna().sum()
# Out:
# product_category_name            0
# product_category_name_english    0
# dtype: int64

# %%
print("Jumlah duplikasi", product_category_df.duplicated().sum())
# Out:
# Jumlah duplikasi 0

# %%
product_category_df.describe()
# Out:
#        product_category_name product_category_name_english
# count                     71                            71
# unique                    71                            71
# top             beleza_saude                 health_beauty
# freq                       1                             1

# %% [markdown]
# **Steps to Take:**
# - Data sudah bersih, sehingga tidak ada penanganan khusus

# %% [markdown]
# #### Identifying products_df problem

# %%
products_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32951 entries, 0 to 32950
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   product_id                  32951 non-null  object
#  1   product_category_name       32341 non-null  object
#  2   product_name_lenght         32341 non-null  float64
#  3   product_description_lenght  32341 non-null  float64
#  4   product_photos_qty          32341 non-null  float64
#  5   product_weight_g            32949 non-null  float64
#  6   product_length_cm           32949 non-null  float64
#  7   product_height_cm           32949 non-null  float64
#  8   product_width_cm            32949 non-null  float64
# dtypes: float64(7), object(2)
# memory usage: 2.3+ MB

# %%
products_df.isna().sum()
# Out:
# product_id                      0
# product_category_name         610
# product_name_lenght           610
# product_description_lenght    610
# product_photos_qty            610
# product_weight_g                2
# product_length_cm               2
# product_height_cm               2
# product_width_cm                2
# dtype: int64

# %%
print("Jumlah duplikasi", products_df.duplicated().sum())
# Out:
# Jumlah duplikasi 0

# %%
products_df.describe()
# Out:
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# count         32341.000000                32341.000000        32341.000000
# mean             48.476949                  771.495285            2.188986
# std              10.245741                  635.115225            1.736766
# min               5.000000                    4.000000            1.000000
# 25%              42.000000                  339.000000            1.000000
# 50%              51.000000                  595.000000            1.000000
# 75%              57.000000                  972.000000            3.000000
# max              76.000000                 3992.000000           20.000000
#
#        product_weight_g  product_length_cm  product_height_cm  \
# count      32949.000000       32949.000000       32949.000000
# mean        2276.472488          30.815078          16.937661
# std         4282.038731          16.914458          13.637554
# min            0.000000           7.000000           2.000000
# 25%          300.000000          18.000000           8.000000
# 50%          700.000000          25.000000          13.000000
# 75%         1900.000000          38.000000          21.000000
# max        40425.000000         105.000000         105.000000
#
#        product_width_cm
# count      32949.000000
# mean          23.196728
# std           12.079047
# min            6.000000
# 25%           15.000000
# 50%           20.000000
# 75%           30.000000
# max          118.000000

# %% [markdown]
# **Steps to Take:**
# - Mengisi missing value di kolom product_category_name menjadi unknown
# - sisa kolom lain diisi median

# %% [markdown]
# #### Identifying sellers_df problem

# %%
sellers_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3095 entries, 0 to 3094
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   seller_id               3095 non-null   object
#  1   seller_zip_code_prefix  3095 non-null   int64
#  2   seller_city             3095 non-null   object
#  3   seller_state            3095 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 96.8+ KB

# %%
sellers_df.isna().sum()
# Out:
# seller_id                 0
# seller_zip_code_prefix    0
# seller_city               0
# seller_state              0
# dtype: int64

# %%
print("Jumlah duplikasi", sellers_df.duplicated().sum())
# Out:
# Jumlah duplikasi 0

# %%
sellers_df.describe()
# Out:
#        seller_zip_code_prefix
# count             3095.000000
# mean             32291.059451
# std              32713.453830
# min               1001.000000
# 25%               7093.500000
# 50%              14940.000000
# 75%              64552.500000
# max              99730.000000

# %% [markdown]
# **Steps to Take:**
# - Data sudah bersih, sehingga tidak perlu penanganan khusus.

# %% [markdown]
# ### Cleaning Data

# %% [markdown]
# ##Tabel geolocation_df
# #### Fixing data duplicate problem

# %% [markdown]
# #### Fixing data duplicate problem

# %%
geolocation_df[geolocation_df.duplicated()]
# Out:
#          geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 15                              1046       -23.546081       -46.644820
# 44                              1046       -23.546081       -46.644820
# 65                              1046       -23.546081       -46.644820
# 66                              1009       -23.546935       -46.636588
# 67                              1046       -23.546081       -46.644820
# ...                              ...              ...              ...
# 1000153                        99970       -28.343273       -51.873734
# 1000154                        99950       -28.070493       -52.011342
# 1000159                        99900       -27.877125       -52.224882
# 1000160                        99950       -28.071855       -52.014716
# 1000162                        99950       -28.070104       -52.018658
#
#         geolocation_city geolocation_state
# 15             sao paulo                SP
# 44             sao paulo                SP
# 65             sao paulo                SP
# 66             sao paulo                SP
# 67             sao paulo                SP
# ...                  ...               ...
# 1000153          ciriaco                RS
# 1000154         tapejara                RS
# 1000159   getulio vargas                RS
# 1000160         tapejara                RS
# 1000162         tapejara                RS
#
# [261831 rows x 5 columns]

# %%
geolocation_df.drop_duplicates(inplace=True)

# %%
print("Jumlah duplikasi: ", geolocation_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %% [markdown]
# ## Tabel order_items_df
# #### Fixing data type problem

# %%
order_items_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   order_id             112650 non-null  object
#  1   order_item_id        112650 non-null  int64
#  2   product_id           112650 non-null  object
#  3   seller_id            112650 non-null  object
#  4   shipping_limit_date  112650 non-null  object
#  5   price                112650 non-null  float64
#  6   freight_value        112650 non-null  float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 6.0+ MB

# %%
datetime_columns = ["shipping_limit_date"]

for column in datetime_columns:
  order_items_df[column] = pd.to_datetime(order_items_df[column])

# %%
#Cek kembali apakah tipe data kolom shipping limit date sudah berubah
order_items_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   order_id             112650 non-null  object
#  1   order_item_id        112650 non-null  int64
#  2   product_id           112650 non-null  object
#  3   seller_id            112650 non-null  object
#  4   shipping_limit_date  112650 non-null  datetime64[ns]
#  5   price                112650 non-null  float64
#  6   freight_value        112650 non-null  float64
# dtypes: datetime64[ns](1), float64(2), int64(1), object(3)
# memory usage: 6.0+ MB

# %%
order_items_df.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#   shipping_limit_date   price  freight_value
# 0 2017-09-19 09:45:35   58.90          13.29
# 1 2017-05-03 11:05:13  239.90          19.93
# 2 2018-01-18 14:48:30  199.00          17.87
# 3 2018-08-15 10:10:18   12.99          12.79
# 4 2017-02-13 13:57:51  199.90          18.14

# %% [markdown]
# ## Tabel order_reviews_df
# #### Fixing missing value problem

# %%
order_reviews_df.isna().sum()
# Out:
# review_id                      0
# order_id                       0
# review_score                   0
# review_comment_title       87656
# review_comment_message     58247
# review_creation_date           0
# review_answer_timestamp        0
# dtype: int64

# %%
#Mengisi kolom comment title dan message yang null diisi dengan no title dan no review

order_reviews_df['review_comment_title'] = \
order_reviews_df['review_comment_title'].fillna('No Title')

order_reviews_df['review_comment_message'] = \
order_reviews_df['review_comment_message'].fillna('No Review')

# %%
order_reviews_df.isna().sum()
# Out:
# review_id                  0
# order_id                   0
# review_score               0
# review_comment_title       0
# review_comment_message     0
# review_creation_date       0
# review_answer_timestamp    0
# dtype: int64

# %%
order_reviews_df.head()
# Out:
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3  e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4  f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
#
#    review_score review_comment_title  \
# 0             4             No Title
# 1             5             No Title
# 2             5             No Title
# 3             5             No Title
# 4             5             No Title
#
#                               review_comment_message review_creation_date  \
# 0                                          No Review  2018-01-18 00:00:00
# 1                                          No Review  2018-03-10 00:00:00
# 2                                          No Review  2018-02-17 00:00:00
# 3              Recebi bem antes do prazo estipulado.  2017-04-21 00:00:00
# 4  Parabéns lojas lannister adorei comprar pela I...  2018-03-01 00:00:00
#
#   review_answer_timestamp
# 0     2018-01-18 21:46:59
# 1     2018-03-11 03:05:13
# 2     2018-02-18 14:36:24
# 3     2017-04-21 22:02:06
# 4     2018-03-02 10:26:53

# %% [markdown]
# #### Fixing data type problem

# %%
order_reviews_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99224 entries, 0 to 99223
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   review_id                99224 non-null  object
#  1   order_id                 99224 non-null  object
#  2   review_score             99224 non-null  int64
#  3   review_comment_title     99224 non-null  object
#  4   review_comment_message   99224 non-null  object
#  5   review_creation_date     99224 non-null  object
#  6   review_answer_timestamp  99224 non-null  object
# dtypes: int64(1), object(6)
# memory usage: 5.3+ MB

# %%
datetime_columns = ["review_creation_date", "review_answer_timestamp"]

for column in datetime_columns:
  order_reviews_df[column] = pd.to_datetime(order_reviews_df[column])

# %%
order_reviews_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99224 entries, 0 to 99223
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   review_id                99224 non-null  object
#  1   order_id                 99224 non-null  object
#  2   review_score             99224 non-null  int64
#  3   review_comment_title     99224 non-null  object
#  4   review_comment_message   99224 non-null  object
#  5   review_creation_date     99224 non-null  datetime64[ns]
#  6   review_answer_timestamp  99224 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), int64(1), object(4)
# memory usage: 5.3+ MB

# %% [markdown]
# ##Tabel orders_df
#
# #### Fixing missing value problem

# %%
orders_df.isna().sum()
# Out:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 160
# order_delivered_carrier_date     1783
# order_delivered_customer_date    2965
# order_estimated_delivery_date       0
# dtype: int64

# %%
orders_df[orders_df.order_approved_at.isna()]
# Out:
#                                order_id                       customer_id  \
# 1130   00b1cb0320190ca0daa2c88b35206009  3532ba38a3fd242259a514ac2b6ae6b6
# 1801   ed3efbd3a87bea76c2812c66a0b32219  191984a8ba4cbb2145acb4fe35b69664
# 1868   df8282afe61008dc26c6c31011474d02  aa797b187b5466bc6925aaaa4bb3bed1
# 2029   8d4c637f1accf7a88a4555f02741e606  b1dd715db389a2077f43174e7a675d07
# 2161   7a9d4c7f9b068337875b95465330f2fc  7f71ae48074c0cfec9195f88fcbfac55
# ...                                 ...                               ...
# 97696  5a00b4d35edffc56b825c3646a99ba9d  6a3bdf004ca96338fb5fad1b8d93c2e6
# 98415  227c804e2a44760671a6a5697ea549e4  62e7477e75e542243ee62a0ba73f410f
# 98909  e49e7ce1471b4693482d40c2bd3ad196  e4e7ab3f449aeb401f0216f86c2104db
# 99283  3a3cddda5a7c27851bd96c3313412840  0b0d6095c5555fe083844281f6b093bb
# 99347  a89abace0dcc01eeb267a9660b5ac126  2f0524a7b1b3845a1a57fcf3910c4333
#
#       order_status order_purchase_timestamp order_approved_at  \
# 1130      canceled      2018-08-28 15:26:39               NaN
# 1801      canceled      2018-09-20 13:54:16               NaN
# 1868      canceled      2017-03-04 12:14:30               NaN
# 2029      canceled      2018-08-29 16:27:49               NaN
# 2161      canceled      2017-05-01 16:12:39               NaN
# ...            ...                      ...               ...
# 97696     canceled      2017-07-02 15:38:46               NaN
# 98415     canceled      2017-09-28 15:02:56               NaN
# 98909     canceled      2018-08-07 11:16:28               NaN
# 99283     canceled      2018-08-31 16:13:44               NaN
# 99347     canceled      2018-09-06 18:45:47               NaN
#
#       order_delivered_carrier_date order_delivered_customer_date  \
# 1130                           NaN                           NaN
# 1801                           NaN                           NaN
# 1868                           NaN                           NaN
# 2029                           NaN                           NaN
# 2161                           NaN                           NaN
# ...                            ...                           ...
# 97696                          NaN                           NaN
# 98415                          NaN                           NaN
# 98909                          NaN                           NaN
# 99283                          NaN                           NaN
# 99347                          NaN                           NaN
#
#       order_estimated_delivery_date
# 1130            2018-09-12 00:00:00
# 1801            2018-10-17 00:00:00
# 1868            2017-04-10 00:00:00
# 2029            2018-09-13 00:00:00
# 2161            2017-05-30 00:00:00
# ...                             ...
# 97696           2017-07-25 00:00:00
# 98415           2017-10-16 00:00:00
# 98909           2018-08-10 00:00:00
# 99283           2018-10-01 00:00:00
# 99347           2018-09-27 00:00:00
#
# [160 rows x 8 columns]

# %% [markdown]
# **Insight:**
# - Data tanggal tersebut dibiarkan saja kosong, karena kejadian tersebut sepertinya belum terlaksana atau terjadi

# %% [markdown]
# #### Fixing data type *problem*

# %%
orders_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  object
#  4   order_approved_at              99281 non-null  object
#  5   order_delivered_carrier_date   97658 non-null  object
#  6   order_delivered_customer_date  96476 non-null  object
#  7   order_estimated_delivery_date  99441 non-null  object
# dtypes: object(8)
# memory usage: 6.1+ MB

# %%
datetime_columns = ["order_approved_at", "order_delivered_carrier_date", "order_delivered_customer_date", "order_estimated_delivery_date"]

for column in datetime_columns:
  orders_df[column] = pd.to_datetime(orders_df[column])

# %%
# cek kembali apakah kolom-kolom tersebut tipe datanya berubah
orders_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  object
#  4   order_approved_at              99281 non-null  datetime64[ns]
#  5   order_delivered_carrier_date   97658 non-null  datetime64[ns]
#  6   order_delivered_customer_date  96476 non-null  datetime64[ns]
#  7   order_estimated_delivery_date  99441 non-null  datetime64[ns]
# dtypes: datetime64[ns](4), object(4)
# memory usage: 6.1+ MB

# %% [markdown]
# ##Tabel products_df
#
# #### Fixing missing value problem

# %%
products_df.isna().sum()
# Out:
# product_id                      0
# product_category_name         610
# product_name_lenght           610
# product_description_lenght    610
# product_photos_qty            610
# product_weight_g                2
# product_length_cm               2
# product_height_cm               2
# product_width_cm                2
# dtype: int64

# %%
products_df[products_df.product_category_name.isna()]
# Out:
#                              product_id product_category_name  \
# 105    a41e356c76fab66334f36de622ecbd3a                   NaN
# 128    d8dee61c2034d6d075997acef1870e9b                   NaN
# 145    56139431d72cd51f19eb9f7dae4d1617                   NaN
# 154    46b48281eb6d663ced748f324108c733                   NaN
# 197    5fb61f482620cb672f5e586bb132eae9                   NaN
# ...                                 ...                   ...
# 32515  b0a0c5dd78e644373b199380612c350a                   NaN
# 32589  10dbe0fbaa2c505123c17fdc34a63c56                   NaN
# 32616  bd2ada37b58ae94cc838b9c0569fecd8                   NaN
# 32772  fa51e914046aab32764c41356b9d4ea4                   NaN
# 32852  c4ceee876c82b8328e9c293fa0e1989b                   NaN
#
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# 105                    NaN                         NaN                 NaN
# 128                    NaN                         NaN                 NaN
# 145                    NaN                         NaN                 NaN
# 154                    NaN                         NaN                 NaN
# 197                    NaN                         NaN                 NaN
# ...                    ...                         ...                 ...
# 32515                  NaN                         NaN                 NaN
# 32589                  NaN                         NaN                 NaN
# 32616                  NaN                         NaN                 NaN
# 32772                  NaN                         NaN                 NaN
# 32852                  NaN                         NaN                 NaN
#
#        product_weight_g  product_length_cm  product_height_cm  \
# 105               650.0               17.0               14.0
# 128               300.0               16.0                7.0
# 145               200.0               20.0               20.0
# 154             18500.0               41.0               30.0
# 197               300.0               35.0                7.0
# ...                 ...                ...                ...
# 32515            1800.0               30.0               20.0
# 32589             800.0               30.0               10.0
# 32616             200.0               21.0                8.0
# 32772            1300.0               45.0               16.0
# 32852             700.0               28.0                3.0
#
#        product_width_cm
# 105                12.0
# 128                20.0
# 145                20.0
# 154                41.0
# 197                12.0
# ...                 ...
# 32515              70.0
# 32589              23.0
# 32616              16.0
# 32772              45.0
# 32852              43.0
#
# [610 rows x 9 columns]

# %%
products_df['product_category_name'] = products_df['product_category_name'].fillna('unknown')

# %%
columns = ['product_name_lenght', 'product_description_lenght', 'product_photos_qty']

for col in columns:
    products_df[col] = products_df[col].fillna(products_df[col].median())

# %%
#Mengisi kolom product weight g, produk length_cm,... yang null menjadi nilai median kolom

column = ['product_weight_g', 'product_length_cm',
              'product_height_cm', 'product_width_cm']

for col in column:
    products_df[col].fillna(products_df[col].median(), inplace=True)
# Out:
# /tmp/ipykernel_303/966828695.py:7: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   products_df[col].fillna(products_df[col].median(), inplace=True)

# %%
products_df.isna().sum()
# Out:
# product_id                    0
# product_category_name         0
# product_name_lenght           0
# product_description_lenght    0
# product_photos_qty            0
# product_weight_g              0
# product_length_cm             0
# product_height_cm             0
# product_width_cm              0
# dtype: int64

# %% [markdown]
# ##Exploratory Data Analysis

# %% [markdown]
# ###Explore customers_df

# %%
customers_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_id               99441 non-null  object
#  1   customer_unique_id        99441 non-null  object
#  2   customer_zip_code_prefix  99441 non-null  int64
#  3   customer_city             99441 non-null  object
#  4   customer_state            99441 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 3.8+ MB

# %%
customers_df.describe()
# Out:
#        customer_zip_code_prefix
# count              99441.000000
# mean               35137.474583
# std                29797.938996
# min                 1003.000000
# 25%                11347.000000
# 50%                24416.000000
# 75%                58900.000000
# max                99990.000000

# %%
customers_df['customer_state'].value_counts()
# Out:
# customer_state
# SP    41746
# RJ    12852
# MG    11635
# RS     5466
# PR     5045
# SC     3637
# BA     3380
# DF     2140
# ES     2033
# GO     2020
# PE     1652
# CE     1336
# PA      975
# MT      907
# MA      747
# MS      715
# PB      536
# PI      495
# RN      485
# AL      413
# SE      350
# TO      280
# RO      253
# AM      148
# AC       81
# AP       68
# RR       46
# Name: count, dtype: int64

# %% [markdown]
# **Insight:**
# - Customer paling banyak berada di state SP
# - Customer paling sedikit berada di state RR

# %% [markdown]
# ###Explore orders_df

# %%
orders_df['order_status'].value_counts()
# Out:
# order_status
# delivered      96478
# shipped         1107
# canceled         625
# unavailable      609
# invoiced         314
# processing       301
# created            5
# approved           2
# Name: count, dtype: int64

# %%
orders_df['order_purchase_timestamp'] = pd.to_datetime(orders_df['order_purchase_timestamp'])

# %%
orders_df['order_purchase_timestamp'].dt.year.value_counts()
# Out:
# order_purchase_timestamp
# 2018    54011
# 2017    45101
# 2016      329
# Name: count, dtype: int64

# %% [markdown]
# **Insight:**
# - order status paling banyak berada pada fase sudah terkirim (delivered)
# - Order paling banyak terjadi pada tahun 2018

# %% [markdown]
# ###Explore order_items_df

# %%
order_items_df.describe()
# Out:
#        order_item_id            shipping_limit_date          price  \
# count  112650.000000                         112650  112650.000000
# mean        1.197834  2018-01-07 15:36:52.192685312     120.653739
# min         1.000000            2016-09-19 00:15:34       0.850000
# 25%         1.000000     2017-09-20 20:57:27.500000      39.900000
# 50%         1.000000            2018-01-26 13:59:35      74.990000
# 75%         1.000000  2018-05-10 14:34:00.750000128     134.900000
# max        21.000000            2020-04-09 22:35:08    6735.000000
# std         0.705124                            NaN     183.633928
#
#        freight_value
# count  112650.000000
# mean       19.990320
# min         0.000000
# 25%        13.080000
# 50%        16.260000
# 75%        21.150000
# max       409.680000
# std        15.806405

# %%
order_items_df['price'].describe()
# Out:
# count    112650.000000
# mean        120.653739
# std         183.633928
# min           0.850000
# 25%          39.900000
# 50%          74.990000
# 75%         134.900000
# max        6735.000000
# Name: price, dtype: float64

# %% [markdown]
# **Insight:**
# - Rentang harga produk yang dibeli customer beradaa di range harga 0.85 sampai 6735
# - Harga ongkir paling murah adalah 0
# - Harga ongkir paling mahal adalah 409.68

# %% [markdown]
# ##Explore order_reviews_df

# %%
order_reviews_df.head()
# Out:
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3  e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4  f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
#
#    review_score review_comment_title  \
# 0             4             No Title
# 1             5             No Title
# 2             5             No Title
# 3             5             No Title
# 4             5             No Title
#
#                               review_comment_message review_creation_date  \
# 0                                          No Review           2018-01-18
# 1                                          No Review           2018-03-10
# 2                                          No Review           2018-02-17
# 3              Recebi bem antes do prazo estipulado.           2017-04-21
# 4  Parabéns lojas lannister adorei comprar pela I...           2018-03-01
#
#   review_answer_timestamp
# 0     2018-01-18 21:46:59
# 1     2018-03-11 03:05:13
# 2     2018-02-18 14:36:24
# 3     2017-04-21 22:02:06
# 4     2018-03-02 10:26:53

# %%
order_reviews_df['review_score'].value_counts()
# Out:
# review_score
# 5    57328
# 4    19142
# 1    11424
# 3     8179
# 2     3151
# Name: count, dtype: int64

# %%
order_reviews_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99224 entries, 0 to 99223
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   review_id                99224 non-null  object
#  1   order_id                 99224 non-null  object
#  2   review_score             99224 non-null  int64
#  3   review_comment_title     99224 non-null  object
#  4   review_comment_message   99224 non-null  object
#  5   review_creation_date     99224 non-null  datetime64[ns]
#  6   review_answer_timestamp  99224 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), int64(1), object(4)
# memory usage: 5.3+ MB

# %% [markdown]
# **Insight:**
# - Mayoritas customer memberikan rating 5
# - Namun terdapat minoritas yang memberikan rating bawah (1,2,3) yang belum diketahui penyebabnya apa

# %% [markdown]
# ##Explore order_payments_df

# %%
order_payments_df.sample(10)
# Out:
#                                order_id  payment_sequential payment_type  \
# 56037  e088317b8ae2544100b69e8e3dd0d3c5                   1      voucher
# 34399  2359b971147acb269d1cdd25c07c704d                   1  credit_card
# 13518  fb5ae559d53a2c9ad1f34f3b98085457                   1  credit_card
# 14362  ccf804e764ed5650cd8759557269dc13                   1  credit_card
# 43317  df2afb0d21253af8ac80fefed51bb52e                   1  credit_card
# 80825  ea25b59c25bc728231bbd0e8b6134ef1                   1  credit_card
# 4268   d08c5166c66141d063d3f11027334ac9                   1  credit_card
# 71080  b50950170914e4e305ce324278513006                   1       boleto
# 35259  1486436c20fbfcb9dbce0d90820b86a1                   1  credit_card
# 49347  2218e4b81089f8cf52139915bdc1e48d                   1  credit_card
#
#        payment_installments  payment_value
# 56037                     1         156.19
# 34399                     3         161.42
# 13518                     1          59.04
# 14362                     1           2.20
# 43317                     8         236.97
# 80825                     1         148.15
# 4268                      2         128.21
# 71080                     1          76.86
# 35259                     2          24.66
# 49347                    10         194.08

# %%
order_payments_df['payment_type'].value_counts()
# Out:
# payment_type
# credit_card    76795
# boleto         19784
# voucher         5775
# debit_card      1529
# not_defined        3
# Name: count, dtype: int64

# %% [markdown]
# **Insight:**
# - Mayoritas customer menggunakan credit card sebagai alat pembayaran

# %% [markdown]
# ##Explore products_df & order_items_df & orders_df

# %%
product_sales = order_items_df.merge(products_df, on='product_id')

# %%
product_sales = product_sales.merge(product_category_df, on='product_category_name')

# %%
product_sales.sample(5)
# Out:
#                                order_id  order_item_id  \
# 42340  61c79497eea86e34bf9354c13313b7a8              1
# 9995   1751f4e14a08d5188324c3a04175f76f              2
# 17524  28cf49bbfe2683759d3cf866b7fda22f              1
# 6683   0f597abb3c3850157138723eceba3f1c              1
# 72858  a87b1e2e028f2dd7b4f77afd0f1da268              2
#
#                              product_id                         seller_id  \
# 42340  ed2067a9c1f79553088a3c67b99a9f97  cbd996ad3c1b7dc71fd0e5f5df9087e2
# 9995   712c57780310856377c327e662653625  b8578d2d823bd8e251f6fdd02b40902d
# 17524  825993135690981b6014a46dbe75707e  1025f0e2d44d7041d6cf58b6550e0bfa
# 6683   e6c30d6c9696ee10542e7e25dcdffa92  1127b7f2594683f2510f1c2c834a486b
# 72858  1a428b685ede76217c9efb550c4aaa59  d2374cbcbb3ca4ab1086534108cc3ab7
#
#       shipping_limit_date  price  freight_value product_category_name  \
# 42340 2018-03-21 00:56:15  56.97          19.37             alimentos
# 9995  2018-07-24 15:55:14  31.90          25.46         esporte_lazer
# 17524 2018-01-25 16:00:35  10.00          15.10      moveis_decoracao
# 6683  2018-03-21 21:48:52  89.21          20.67    ferramentas_jardim
# 72858 2018-08-28 03:35:13  22.90          18.26       cama_mesa_banho
#
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# 42340                 52.0                       919.0                 1.0
# 9995                  36.0                      1228.0                 1.0
# 17524                 45.0                       427.0                 1.0
# 6683                  45.0                       250.0                 1.0
# 72858                 49.0                       117.0                 1.0
#
#        product_weight_g  product_length_cm  product_height_cm  \
# 42340             750.0               16.0               12.0
# 9995              800.0               25.0               23.0
# 17524            1000.0               20.0               15.0
# 6683             1200.0               52.0                8.0
# 72858             400.0               40.0                4.0
#
#        product_width_cm product_category_name_english
# 42340              15.0                          food
# 9995               25.0                sports_leisure
# 17524              20.0               furniture_decor
# 6683               11.0                  garden_tools
# 72858              30.0                bed_bath_table

# %%
product_sales = product_sales.merge(orders_df, on='order_id')

# %%
product_sales.sample(5)
# Out:
#                                order_id  order_item_id  \
# 66578  9a6a7ea0e1523950885c7b716b1766cc              1
# 72051  a69ec1a52a9dc2098fa6fbe6a47545a7              1
# 51653  7748e0d22cb39dacfbbe50ab2cb768fa              1
# 60431  8bc4ec47148eae2b4ca051dd24c25a86              2
# 48646  70263b76209f24d8b55c928b82f19afa              1
#
#                              product_id                         seller_id  \
# 66578  66a7ca628024ae587fe4499b255bc26b  8c5e007d7bd5693fa1386ffefbc99f6c
# 72051  ecaae002060173ec59f5b168cbd55d70  6338ea67c41078a46ad99cc009654956
# 51653  ebf1c13032246ea801765e8cb5417365  cb41bfbcbda0aea354a834ab222f9a59
# 60431  42a2c92a0979a949ca4ea89ec5c7b934  813348c996469b40f2e028d5429d3495
# 48646  5d52927f3cf2e3266c5dd6e4d2dd566a  a066df7361163e7ddc5d7452dd17448b
#
#       shipping_limit_date   price  freight_value  product_category_name  \
# 66578 2018-07-05 22:31:21   65.99          15.56           beleza_saude
# 72051 2017-12-15 01:15:25   32.90          14.76             automotivo
# 51653 2017-12-04 09:31:08  399.00          54.33        casa_construcao
# 60431 2017-11-20 22:15:42   58.90           8.56  utilidades_domesticas
# 48646 2018-01-02 17:37:24   59.90          15.17              telefonia
#
#        product_name_lenght  product_description_lenght  ...  \
# 66578                 39.0                       599.0  ...
# 72051                 51.0                      1741.0  ...
# 51653                 39.0                      1190.0  ...
# 60431                 41.0                       799.0  ...
# 48646                 52.0                       526.0  ...
#
#        product_height_cm  product_width_cm  product_category_name_english  \
# 66578               12.0              17.0                  health_beauty
# 72051               24.0              15.0                           auto
# 51653               80.0              50.0              home_construction
# 60431               47.0              27.0                     housewares
# 48646                6.0              13.0                      telephony
#
#                             customer_id  order_status  \
# 66578  0af0d84c00114b0c3c81089011657860     delivered
# 72051  909e605a5ecf709a35b217b52ac2dbf6     delivered
# 51653  6a933d575369fd2e59732c81a51ab189     delivered
# 60431  3597ba3579c46b170518b6cdb8e21b58     delivered
# 48646  22ae01e09f134b81b464f94e52dddc30     delivered
#
#       order_purchase_timestamp   order_approved_at  \
# 66578      2018-07-03 21:44:43 2018-07-05 16:16:42
# 72051      2017-12-11 01:05:34 2017-12-11 01:15:25
# 51653      2017-11-28 09:10:12 2017-11-28 09:34:19
# 60431      2017-11-14 22:01:08 2017-11-14 22:15:42
# 48646      2017-12-26 17:27:17 2017-12-26 17:37:24
#
#       order_delivered_carrier_date order_delivered_customer_date  \
# 66578          2018-07-05 07:25:00           2018-07-10 16:53:48
# 72051          2017-12-13 00:18:34           2017-12-29 14:42:13
# 51653          2017-12-01 21:52:37           2017-12-05 20:17:54
# 60431          2017-11-16 22:33:52           2017-11-22 21:16:50
# 48646          2017-12-27 16:58:41           2018-01-04 21:56:06
#
#       order_estimated_delivery_date
# 66578                    2018-08-06
# 72051                    2018-01-08
# 51653                    2017-12-12
# 60431                    2017-12-04
# 48646                    2018-01-30
#
# [5 rows x 23 columns]

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ### Pertanyaan 1: Bagaimana distribusi review score pelanggan pada 3 bulan terakhir?

# %%
# Ambil tanggal terakhir di dataset
last_date = order_reviews_df['review_creation_date'].max()

# Filter 3 bulan terakhir
filtered_reviews = order_reviews_df[
    order_reviews_df['review_creation_date'] >= (last_date - pd.DateOffset(months=3))
]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))
sns.countplot(x='review_score', data=filtered_reviews)

plt.title("Distribusi Review Score (3 Bulan Terakhir)")
plt.xlabel("Review Score")
plt.ylabel("Jumlah Review")

plt.show()

# %% [markdown]
# ### Pertanyaan 2: Kategori produk apa yang memiliki jumlah penjualan tertinggi berdasarkan jumlah transaksi pada tahun 2017-2018?

# %%
product_sales_filtered = product_sales[
    (product_sales['order_purchase_timestamp'].dt.year >= 2017) &
    (product_sales['order_purchase_timestamp'].dt.year <= 2018)
]
top_category = product_sales_filtered[
    'product_category_name_english'
].value_counts().head(10)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10,6))

sns.barplot(
    x=top_category.values,
    y=top_category.index
)

plt.title("Top 10 Kategori Produk Terlaris periode (2017–2018)")
plt.xlabel("Jumlah Transaksi")
plt.ylabel("Kategori Produk")

plt.show()

# %% [markdown]
# ## Conclusion & Recommendation

# %% [markdown]
# - **Conclusion pertanyaan 1:**
#
#   Berdasarkan analisis distribusi review_score, mayoritas pelanggan memberikan rating tinggi (4 dan 5). Hal ini menunjukkan bahwa secara umum tingkat kepuasan pelanggan terhadap layanan dan produk tergolong baik.
#
#   Namun, masih terdapat sebagian pelanggan yang memberikan rating rendah, yang mengindikasikan adanya pengalaman negatif pada sebagian transaksi.
# - **Conclusion pertanyaan 2:**
#
#   Kategori penjualan produk tertinggi berada di kategori produk bed_bath_table, diikuti oleh kategori produk health_beauty dan sports_leisure. Hal ini menunjukkan bahwa kategori-kategori tersebut memiliki permintaan yang tinggi di pasar dan berpotensi menjadi fokus bisnis utama untuk meningkatkan penjualan.

# %% [markdown]
# **Rekomendasi Action Item:**
# - Fokus pada kategori produk terlaris
# - Optimalkan promosi (diskon, program loyalitas custoer, dll,)
# - Walaupun rating sudah tinggi, pertahankan kualitas produk dan layanan
# - Untuk rating 1 & 2 dianalisis lebih lanjut apa permasalahan utamanya.
